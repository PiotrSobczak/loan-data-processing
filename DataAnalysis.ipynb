# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
# Setting propeties for displaying all DF columns & better readibility
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv("/home/psobczak/Downloads/lending-club-loan-data/loan.csv", low_memory=False)
# Out:
# -------------------------------------------------
# ParserError     Traceback (most recent call last)
# <ipython-input-59-6bc3504a4801> in <module>
# ----> 1 df = pd.read_csv("/home/psobczak/Downloads/lending-club-loan-data/loan.csv", low_memory=False)
#
# ~/PycharmProjects/LoanAnalysis/venv/lib64/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
df.head(10)
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN NaN         2500       2500         2500.0            36 months
# 1 NaN NaN         30000      30000        30000.0           60 months
# 2 NaN NaN         5000       5000         5000.0            36 months
# 3 NaN NaN         4000       4000         4000.0            36 months
# 4 NaN NaN         30000      30000        30000.0           60 months
# 5 NaN NaN         5550       5550         5550.0            36 months
# 6 NaN NaN         2000       2000         2000.0            36 months
# 7 NaN NaN         6000       6000         6000.0            36 months
# 8 NaN NaN         5000       5000         5000.0            36 months
# 9 NaN NaN         6000       6000         6000.0            36 months
#
#    int_rate  installment grade sub_grade            emp_title emp_length  \
# 0  13.56     84.92        C     C1        Chef                 10+ years
# ...

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=145)

# %%
# Getting rid of columns filled with NaNs only, 3 columns are removed
df_filtered = df.dropna(how='all', axis='columns')
df_filtered.head(10)
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=142)

# %%
# Checking if there are any duplicates in loan.csv file based on first 50 columns to reduce computation time
df_duplicated = df_filtered.loc[df_filtered.duplicated(subset=df_filtered.columns.tolist()[:50], keep='first')]
df_duplicated
# Out:
# Empty DataFrame
# ...

# %%
# Calculating the correlation between Dataframe columns
df_corr = df_filtered.corr()
df_corr
# Out:
#                                             loan_amnt  funded_amnt  \
# loan_amnt                                   1.000000   0.999755
# funded_amnt                                 0.999755   1.000000
# funded_amnt_inv                             0.999038   0.999341
# int_rate                                    0.098083   0.098099
# installment                                 0.945627   0.945969
# annual_inc                                  0.197246   0.197207
# dti                                         0.043542   0.043745
# delinq_2yrs                                -0.009277  -0.009173
# inq_last_6mths                             -0.027840  -0.028132
# mths_since_last_delinq                     -0.010849  -0.010851
# mths_since_last_record                      0.016293   0.016290
# open_acc                                    0.182229   0.182392
# pub_rec                                    -0.058772  -0.058636
# revol_bal                                   0.316715   0.316643
# ...

# %%
# Checking whether there ano no redundant columns(correlation=1.0 or -1.0)
for col in df_corr.columns:
    if df_corr.loc[df_corr[col]==1.0].shape[0] > 1 or df_corr.loc[df_corr[col]==-1.0].shape[0] > 0:
        print("Redundant column:", col)

# %%
import datetime
df_filtered['issue_d'] = df_filtered['issue_d'].apply(lambda x: datetime.datetime.strptime(x, '%b-%Y'))
df_sorted = df_filtered.sort_values(by=['issue_d'])
df_sorted.head(3)
# Out:
# -------------------------------------------------
# TypeError       Traceback (most recent call last)
# <ipython-input-42-810030e3168c> in <module>
#       1 import datetime
# ----> 2 df_filtered['issue_d'] = df_filtered['issue_d'].apply(lambda x: datetime.datetime.strptime(x, '%b-%Y'))
#       3 df_sorted = df_filtered.sort_values(by=['issue_d'])
#       4 df_sorted['issue_y'] = df_sorted['issue_d'].apply(lambda x: x.split('-')[0])
#
# ~/PycharmProjects/LoanAnalysis/venv/lib64/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-42-810030e3168c> in <lambda>(x)
#       1 import datetime
# ...

# %%
# Plotting number of issued loands per year
df_year = df_sorted[['issue_d']]
df_year['issue_y'] = df_year['issue_d'].apply(lambda x: x.year)
df_year_grouped = df_year.groupby('issue_y') 
df_year_count = df_year_grouped.size()
df_year_count.plot.bar(x='lab', y='val', rot=0)
# Out:
# /home/psobczak/PycharmProjects/LoanAnalysis/venv/lib64/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Plotting number of issued loands per month
df_year_grouped = df_sorted.groupby('issue_d') 
df_monthly_count = df_year_grouped.size()
df_monthly_count.plot.bar(x='lab', y='val', rot=0)
